# %% [markdown]
# # Question 1: Create a dataset as below and display the dataset information.
#
# Display the description of the dataset. Use `describe()`.
# Display the shape of the dataframe. Use `shape`.
# Display the information of the dataframe.
# Only the first five rows
# Only the last five rows.
# Only the rows from index 3 to 5

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'CustomerID': ['C001', 'C002', 'C003', 'C004', 'C004', 'C005', 'C006', 'C007', 'C008', 'C008'],
    'Name': ['John', 'Alice', 'BOB', 'BOBY', 'Eve', 'eve', 'Steve', 'Ramu', 'mary', 'Bob'],
    'Age': [25, 34, 17, 29, 29, 120, -5, np.nan, 220, 30],
    'JoinDate': ['12/1/2024', '11/15/2023', '6/1/2022', '6/1/2022', '12/5/2024', 'invalid_date', np.nan, '1/1/2024', '3/5/2023', '3/5/2023'],
    'MonthlyCharges': [29.85, 56.95, 4000, 75.5, 75.5, 45.99, 60, 49.99, -30, 55],
    'Churn': ['No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', np.nan, 'Yes', 'No']
}

# print data type of data
print(f"Data type of data: {type(data)} \n")


df = pd.DataFrame(data)
display(df)
# Out:
# Data type of data: <class 'dict'>
#   CustomerID   Name    Age      JoinDate  MonthlyCharges Churn
# 0       C001   John   25.0     12/1/2024           29.85    No
# 1       C002  Alice   34.0    11/15/2023           56.95   Yes
# 2       C003    BOB   17.0      6/1/2022         4000.00    No
# 3       C004   BOBY   29.0      6/1/2022           75.50    No
# 4       C004    Eve   29.0     12/5/2024           75.50    No
# 5       C005    eve  120.0  invalid_date           45.99   Yes
# 6       C006  Steve   -5.0           NaN           60.00    No
# 7       C007   Ramu    NaN      1/1/2024           49.99   NaN
# 8       C008   mary  220.0      3/5/2023          -30.00   Yes
# 9       C008    Bob   30.0      3/5/2023           55.00    No

# %%
# a. Display the description of the dataset
display(df.describe())
# Out:
#               Age  MonthlyCharges
# count    9.000000       10.000000
# mean    55.444444      441.878000
# std     70.542737     1250.560418
# min     -5.000000      -30.000000
# 25%     25.000000       46.990000
# 50%     29.000000       55.975000
# 75%     34.000000       71.625000
# max    220.000000     4000.000000

# %%
# b. Display the shape of the dataframe
print(f"Shape of dataframe: {df.shape}")
# Out:
# Shape of dataframe: (10, 6)

# %%
# c. Display the information of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      10 non-null     object
#  1   Name            10 non-null     object
#  2   Age             9 non-null      float64
#  3   JoinDate        9 non-null      object
#  4   MonthlyCharges  10 non-null     float64
#  5   Churn           9 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 612.0+ bytes

# %%
# Only the first five rows
display(df.head(5))
# Out:
#   CustomerID   Name   Age    JoinDate  MonthlyCharges Churn
# 0       C001   John  25.0   12/1/2024           29.85    No
# 1       C002  Alice  34.0  11/15/2023           56.95   Yes
# 2       C003    BOB  17.0    6/1/2022         4000.00    No
# 3       C004   BOBY  29.0    6/1/2022           75.50    No
# 4       C004    Eve  29.0   12/5/2024           75.50    No

# %%
# only the last five rows
display(df.tail(5))
# Out:
#   CustomerID   Name    Age      JoinDate  MonthlyCharges Churn
# 5       C005    eve  120.0  invalid_date           45.99   Yes
# 6       C006  Steve   -5.0           NaN           60.00    No
# 7       C007   Ramu    NaN      1/1/2024           49.99   NaN
# 8       C008   mary  220.0      3/5/2023          -30.00   Yes
# 9       C008    Bob   30.0      3/5/2023           55.00    No

# %%
# Only rows from index 3 to 5
display(df.iloc[3:6])
# Out:
#   CustomerID  Name    Age      JoinDate  MonthlyCharges Churn
# 3       C004  BOBY   29.0      6/1/2022           75.50    No
# 4       C004   Eve   29.0     12/5/2024           75.50    No
# 5       C005   eve  120.0  invalid_date           45.99   Yes

# %% [markdown]
# # Question 2: Create a dataset as below and find out the missing values in the dataset using:
#
# `isnull()`, `isna()`, `notna()`, `notnull()` and using `any()` or `sum()` functions individually with each of them.

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

# Re-creating the dataset correctly
data = {
    'CustomerID': ['C001', 'C002', 'C003', 'C004', 'C004', 'C005', 'C006', 'C007', 'C008', 'C008'],
    'Name': ['John', 'Alice', 'BOB', 'BOBY', 'Eve', 'eve', 'Steve', 'Ramu', 'mary', 'Bob'],
    'Age': [25, 34, 17, 29, 29, 120, -5, np.nan, 220, 30],
    'JoinDate': ['12/1/2024', '11/15/2023', '6/1/2022', '6/1/2022', '12/5/2024', 'invalid_date', np.nan, '1/1/2024', '3/5/2023', '3/5/2023'],
    'MonthlyCharges': [29.85, 56.95, 4000, 75.5, 75.5, 45.99, 60, 49.99, -30, 55],
    'Churn': ['No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', np.nan, 'Yes', 'No']
}

df = pd.DataFrame(data)
display(df)
# Out:
#   CustomerID   Name    Age      JoinDate  MonthlyCharges Churn
# 0       C001   John   25.0     12/1/2024           29.85    No
# 1       C002  Alice   34.0    11/15/2023           56.95   Yes
# 2       C003    BOB   17.0      6/1/2022         4000.00    No
# 3       C004   BOBY   29.0      6/1/2022           75.50    No
# 4       C004    Eve   29.0     12/5/2024           75.50    No
# 5       C005    eve  120.0  invalid_date           45.99   Yes
# 6       C006  Steve   -5.0           NaN           60.00    No
# 7       C007   Ramu    NaN      1/1/2024           49.99   NaN
# 8       C008   mary  220.0      3/5/2023          -30.00   Yes
# 9       C008    Bob   30.0      3/5/2023           55.00    No

# %%
print("1. Using isnull().sum():\n")
print(df.isnull().sum())
print("\n")

print("\n2. Using isna().any():")
print(df.isna().any())
print("\n")

print("\n3. Using notnull().sum() (Non-missing counts):")
print(df.notnull().sum())
print("\n")

print("\n4. Using notna().any() (Check if columns have any valid data):")
print(df.notna().any())
print("\n")
# Out:
# 1. Using isnull().sum():
#
# CustomerID        0
# Name              0
# Age               1
# JoinDate          1
# MonthlyCharges    0
# Churn             1
# dtype: int64
#
#
#
# 2. Using isna().any():
# CustomerID        False
# Name              False
# Age                True
# JoinDate           True
# MonthlyCharges    False
# Churn              True
# dtype: bool
#
#
#
# 3. Using notnull().sum() (Non-missing counts):
# CustomerID        10
# Name              10
# Age                9
# JoinDate           9
# MonthlyCharges    10
# Churn              9
# dtype: int64
#
#
#
# 4. Using notna().any() (Check if columns have any valid data):
# CustomerID        True
# Name              True
# Age               True
# JoinDate          True
# MonthlyCharges    True
# Churn             True
# dtype: bool

# %% [markdown]
# # Question 3: Create a dataset as below and identify the duplicated row with reference to the attribute “CustomerID” and remove the duplicated row.

# %%
import pandas as pd
import numpy as np

# %%
# Create the dataset
data = {
    'CustomerID': ['C001', 'C002', 'C003', 'C004', 'C004', 'C005', 'C006', 'C007', 'C008', 'C008'],
    'Name': ['John', 'Alice', 'BOB', 'BOBY', 'Eve', 'eve', 'Steve', 'Ramu', 'mary', 'Bob'],
    'Age': [25, 34, 17, 29, 29, 120, -5, np.nan, 220, 30],
    'JoinDate': ['12/1/2024', '11/15/2023', '6/1/2022', '6/1/2022', '12/5/2024', 'invalid_date', np.nan, '1/1/2024', '3/5/2023', '3/5/2023'],
    'MonthlyCharges': [29.85, 56.95, 4000, 75.5, 75.5, 45.99, 60, 49.99, -30, 55],
    'Churn': ['No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', np.nan, 'Yes', 'No']
}

df = pd.DataFrame(data)

print("Original DataFrame:")
display(df)
# Out:
# Original DataFrame:
#   CustomerID   Name    Age      JoinDate  MonthlyCharges Churn
# 0       C001   John   25.0     12/1/2024           29.85    No
# 1       C002  Alice   34.0    11/15/2023           56.95   Yes
# 2       C003    BOB   17.0      6/1/2022         4000.00    No
# 3       C004   BOBY   29.0      6/1/2022           75.50    No
# 4       C004    Eve   29.0     12/5/2024           75.50    No
# 5       C005    eve  120.0  invalid_date           45.99   Yes
# 6       C006  Steve   -5.0           NaN           60.00    No
# 7       C007   Ramu    NaN      1/1/2024           49.99   NaN
# 8       C008   mary  220.0      3/5/2023          -30.00   Yes
# 9       C008    Bob   30.0      3/5/2023           55.00    No

# %%
# Identify duplicated rows with reference to 'CustomerID'
duplicates = df[df.duplicated('CustomerID', keep=False)]
print("\nRows with duplicated CustomerID:\n")
display(duplicates)
# Out:
# Rows with duplicated CustomerID:
#   CustomerID  Name    Age   JoinDate  MonthlyCharges Churn
# 3       C004  BOBY   29.0   6/1/2022            75.5    No
# 4       C004   Eve   29.0  12/5/2024            75.5    No
# 8       C008  mary  220.0   3/5/2023           -30.0   Yes
# 9       C008   Bob   30.0   3/5/2023            55.0    No

# %%
# Remove duplicated rows (keeping the first occurrence)
df_cleaned = df.drop_duplicates(subset='CustomerID', keep='first')

print("\nDataFrame after removing duplicates (based on CustomerID):\n")
display(df_cleaned)
# Out:
# DataFrame after removing duplicates (based on CustomerID):
#   CustomerID   Name    Age      JoinDate  MonthlyCharges Churn
# 0       C001   John   25.0     12/1/2024           29.85    No
# 1       C002  Alice   34.0    11/15/2023           56.95   Yes
# 2       C003    BOB   17.0      6/1/2022         4000.00    No
# 3       C004   BOBY   29.0      6/1/2022           75.50    No
# 5       C005    eve  120.0  invalid_date           45.99   Yes
# 6       C006  Steve   -5.0           NaN           60.00    No
# 7       C007   Ramu    NaN      1/1/2024           49.99   NaN
# 8       C008   mary  220.0      3/5/2023          -30.00   Yes

# %% [markdown]
#  # Question 4: Create a dataset as below:
#
# ```
# data = { "Feature1": [10, 20, 30, 40, 50],
# "Feature2": [100, 200, 300, 400, 500],
# "Feature3": [5, 15, 25, 35, 45]
# }
# ```
#
#
# 1.   Perform Min-Max Normalization
# 2.   Perform Z-score Normalization
# 3.   Perform Decimal Scale Normalization

# %%
import pandas as pd
import numpy as np

# Create the dataset
data = {
    "Feature1": [10, 20, 30, 40, 50],
    "Feature2": [100, 200, 300, 400, 500],
    "Feature3": [5, 15, 25, 35, 45]
}
df_norm = pd.DataFrame(data)
print("Original Dataset:")
display(df_norm)
# Out:
# Original Dataset:
#    Feature1  Feature2  Feature3
# 0        10       100         5
# 1        20       200        15
# 2        30       300        25
# 3        40       400        35
# 4        50       500        45

# %%
# 1. Min-Max Normalization: (x - min) / (max - min)
df_min_max = (df_norm - df_norm.min()) / (df_norm.max() - df_norm.min())
print("1. Min-Max Normalized Dataset:")
display(df_min_max)
# Out:
# 1. Min-Max Normalized Dataset:
#    Feature1  Feature2  Feature3
# 0      0.00      0.00      0.00
# 1      0.25      0.25      0.25
# 2      0.50      0.50      0.50
# 3      0.75      0.75      0.75
# 4      1.00      1.00      1.00

# %%
# 2. Z-score Normalization: (x - mean) / std
df_zscore = (df_norm - df_norm.mean()) / df_norm.std()
print("2. Z-score Normalized Dataset:")
display(df_zscore)
# Out:
# 2. Z-score Normalized Dataset:
#    Feature1  Feature2  Feature3
# 0 -1.264911 -1.264911 -1.264911
# 1 -0.632456 -0.632456 -0.632456
# 2  0.000000  0.000000  0.000000
# 3  0.632456  0.632456  0.632456
# 4  1.264911  1.264911  1.264911

# %%
# 3. Decimal Scale Normalization: x / 10^j where 10^j is the smallest power of 10 such that max(|x|)/10^j < 1
def decimal_scaling(df):
    df_scaled = df.copy()
    for col in df_scaled.columns:
        p = df_scaled[col].abs().max()
        j = np.ceil(np.log10(p))
        df_scaled[col] = df_scaled[col] / (10**j)
    return df_scaled

df_decimal = decimal_scaling(df_norm)
print("3. Decimal Scale Normalized Dataset:")
display(df_decimal)
# Out:
# 3. Decimal Scale Normalized Dataset:
#    Feature1  Feature2  Feature3
# 0       0.1       0.1      0.05
# 1       0.2       0.2      0.15
# 2       0.3       0.3      0.25
# 3       0.4       0.4      0.35
# 4       0.5       0.5      0.45

# %% [markdown]
# # Question 5: Write python code to implement KNN classifier (with K =3) for predicting the new point `BMI= 43.6` and `Age= 40` with reference to below dataset.
#
# | BMI | Age | Sugar |
# |--- |--- |--- |
# |33.6|50|1|
# |26.6|30|0|
# |23.4|40|0|
# |43.1|67|0|
# |35.3|23|1|
# |35.9|67|1|
# |36.7|45|1|
# |25.7|46|0|
# |23.3|29|0|
# |31|56|1|

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# Create the dataset
data = {
    'BMI': [33.6, 26.6, 23.4, 43.1, 35.3, 35.9, 36.7, 25.7, 23.3, 31],
    'Age': [50, 30, 40, 67, 23, 67, 45, 46, 29, 56],
    'Sugar': [1, 0, 0, 0, 1, 1, 1, 0, 0, 1]
}

df_knn = pd.DataFrame(data)
display(df_knn)
# Out:
#     BMI  Age  Sugar
# 0  33.6   50      1
# 1  26.6   30      0
# 2  23.4   40      0
# 3  43.1   67      0
# 4  35.3   23      1
# 5  35.9   67      1
# 6  36.7   45      1
# 7  25.7   46      0
# 8  23.3   29      0
# 9  31.0   56      1

# %%
# Features and Target
X = df_knn[['BMI', 'Age']]
y = df_knn['Sugar']

# Initialize KNN with K=3
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the model
knn.fit(X, y)

# Define the new point
new_point = pd.DataFrame([[43.6, 40]], columns=['BMI', 'Age'])

# Predict
prediction = knn.predict(new_point)

print(f"Prediction for BMI=43.6, Age=40: Sugar = {prediction[0]}")
# Out:
# Prediction for BMI=43.6, Age=40: Sugar = 1

# %% [markdown]
# # Question 6: You are provided with the following dataset:
#
# Staff Age Weight Color
# 101 5 20 Brown
# 102 3 8 Black
# 103 2 0.5 Yellow
# 104 4 18 White
# 105 7 9 Brown
#
# Perform the following tasks:
#
# a) Apply one-hot encoding to Color columns.
#
# b) Combine the encoded features with the rest of the dataset.
#
# c) Display the resulting DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Create the dataset
data = {
    'Staff': [101, 102, 103, 104, 105],
    'Age': [5, 3, 2, 4, 7],
    'Weight': [20, 8, 0.5, 18, 9],
    'Color': ['Brown', 'Black', 'Yellow', 'White', 'Brown']
}

df_staff = pd.DataFrame(data)
print("Original DataFrame:")
display(df_staff)
# Out:
# Original DataFrame:
#    Staff  Age  Weight   Color
# 0    101    5    20.0   Brown
# 1    102    3     8.0   Black
# 2    103    2     0.5  Yellow
# 3    104    4    18.0   White
# 4    105    7     9.0   Brown

# %%
# a) Apply one-hot encoding to Color columns
# Get unique colors in the order they appear in the DataFrame
ordered_colors = df_staff['Color'].unique()
print(ordered_colors)
# Create dummy variables, by default pd.get_dummies sorts the columns alphabetically.
color_encoded = pd.get_dummies(df_staff['Color'], prefix='Color')
# Reindex the DataFrame to ensure the columns follow the order of 'ordered_colors'
desired_column_order = [f'Color_{color}' for color in ordered_colors]
color_encoded = color_encoded.reindex(columns=desired_column_order, fill_value=False)
display(color_encoded)
# Out:
# ['Brown' 'Black' 'Yellow' 'White']
#    Color_Brown  Color_Black  Color_Yellow  Color_White
# 0         True        False         False        False
# 1        False         True         False        False
# 2        False        False          True        False
# 3        False        False         False         True
# 4         True        False         False        False

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 2))

# Hide axes
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_frame_on(False)

# Create the table from color_encoded dataframe
table = ax.table(cellText=color_encoded.values, colLabels=color_encoded.columns, cellLoc='center', loc='center')

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

plt.title('Color Encoded DataFrame Visualization')
plt.show()

# %%
# b) Combine the encoded features with the rest of the dataset
df_final = pd.concat([df_staff.drop('Color', axis=1), color_encoded], axis=1)

# c) Display the resulting DataFrame
print("Final DataFrame with One-Hot Encoding:")
display(df_final)
# Out:
# Final DataFrame with One-Hot Encoding:
#    Staff  Age  Weight  Color_Brown  Color_Black  Color_Yellow  Color_White
# 0    101    5    20.0         True        False         False        False
# 1    102    3     8.0        False         True         False        False
# 2    103    2     0.5        False        False          True        False
# 3    104    4    18.0        False        False         False         True
# 4    105    7     9.0         True        False         False        False

# %% [markdown]
# # Question 7: Consider the following dataset of exam scores: [50, 55, 52, 48, 51, 60, 62, 54, 53, 47, 65, 90] and detect the outlier using IQR method, and also plot the box-plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset
scores = [50, 55, 52, 48, 51, 60, 62, 54, 53, 47, 65, 90]

# 1. Detect Outliers using IQR method
Q1 = np.percentile(scores, 25)
Q3 = np.percentile(scores, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = [x for x in scores if x < lower_bound or x > upper_bound]

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
print(f"Detected Outliers: {outliers}")

# 2. Plot the box-plot
plt.figure(figsize=(8, 5))
plt.boxplot(scores, vert=False, patch_artist=True, tick_labels=['Exam Scores'])
plt.title('Box Plot of Exam Scores')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Q1: 50.75
# Q3: 60.5
# IQR: 9.75
# Lower Bound: 36.125
# Upper Bound: 75.125
# Detected Outliers: [90]
