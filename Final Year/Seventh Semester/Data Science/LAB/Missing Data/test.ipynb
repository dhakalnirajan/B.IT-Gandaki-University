# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:/Saugat-Programs/Semester VII/Data Science/Missing Data/train.csv")

print("\n Any Missing values in each column")
print(data.isna().any())
print("\n Count of sum of missing values in each column")
print(data.isna().sum())
# Out:
#  Any Missing values in each column
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool
#
#  Count of sum of missing values in each column
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
