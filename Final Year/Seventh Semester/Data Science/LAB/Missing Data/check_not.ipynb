# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'Age': [10,11,np.nan,np.nan,50],
    'Income': [np.nan,np.nan,10000,50466,np.nan]
})

#just opposite: available = true, not-available = false
print("using notna()")
print(data.notna())
# Out:
# using notna()
#      Age  Income
# 0   True   False
# 1   True   False
# 2  False    True
# 3  False    True
# 4   True   False
