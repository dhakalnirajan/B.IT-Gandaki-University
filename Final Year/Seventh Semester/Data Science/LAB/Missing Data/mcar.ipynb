# %%
import pandas as pd
import numpy as np

data_mcar = pd.DataFrame({
    'Age': [25,30,35,40,45,50],
    'Height': [160,175,180,np.nan,165,170]
})

print("MCAR Example Dataset: ")
print(data_mcar)
# Out:
# MCAR Example Dataset:
#    Age  Height
# 0   25   160.0
# 1   30   175.0
# 2   35   180.0
# 3   40     NaN
# 4   45   165.0
# 5   50   170.0
