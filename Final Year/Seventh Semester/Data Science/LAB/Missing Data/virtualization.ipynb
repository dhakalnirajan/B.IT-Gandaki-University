# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Age': [25,np.nan,35,40,np.nan],
    'Income': [50000,60000,np.nan,70000,80000],
    'Gender': ['Male','Female','Male', 'Female', np.nan]
})

fig, ax = plt.subplots(figsize=(5,4))

msno.matrix(data,ax=ax)

plt.title('Missing Data Matrix')
plt.xlabel('Columns')
plt.ylabel('Rows')
print(data)

plt.show()
# Out:
#     Age   Income  Gender
# 0  25.0  50000.0    Male
# 1   NaN  60000.0  Female
# 2  35.0      NaN    Male
# 3  40.0  70000.0  Female
# 4   NaN  80000.0     NaN
# C:\Users\Saugat\AppData\Roaming\Python\Python312\site-packages\missingno\missingno.py:61: UserWarning: Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
#   warnings.warn(
