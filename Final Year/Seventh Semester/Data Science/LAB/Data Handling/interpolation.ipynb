# %%
import pandas as pd
import numpy as np
data= pd.DataFrame({
    'Age':[25, np.nan,22,50,np.nan],
    'Income': [250000,220000,np.nan,800000, 700000],
    'Gender': ['M','M','F','M','F']
})

# string lai fill gardena yo method le
data_filled=data.interpolate()
print(data_filled)
# Out:
#     Age    Income Gender
# 0  25.0  250000.0      M
# 1  23.5  220000.0      M
# 2  22.0  510000.0      F
# 3  50.0  800000.0      M
# 4  50.0  700000.0      F
# C:\Users\Saugat\AppData\Local\Temp\ipykernel_21292\3019714855.py:10: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data_filled=data.interpolate()
